# %%
import pandas as pd
import re
month = {'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4,'May':5,'Jun':6,'Jul':7,'Aug':8,'Sep':9,'Oct':10,'Nov':11,'Dec':12}

# %%
#Columbia
sch = "columbia"
clbatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
clfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
clpitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
clbatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in clbatting['GP-GS']]
clbatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in clbatting['GP-GS']]
clbatting.GP=clbatting.GP.replace(month)
clbatting=clbatting.astype({'GP': 'int64'})
clbatting['School'] = 'Columbia'
clpitching['School'] = 'Columbia'
clpitching
# Out:
#                # Player    ERA     W-L  APP  GS  CG  SHO  SV     IP    H  ...  \
# 0     36 Tucker, Justin   0.00   1-Jan    6   0   0  0-0   0    7.0    5  ...
# 1   17 Palfrey, Griffin   1.29  Feb-00    5   1   0  0-0   0    7.0    6  ...
# 2        14 Healy, Phil   3.00     0-0    2   0   0  0-0   0    3.0    3  ...
# 3          28 Ogden, JD   4.20     0-2    7   1   0  0-0   1   15.0   15  ...
# 4        27 May, Saajan   4.50  Jan-00    5   0   0  0-0   1   18.0   20  ...
# 5     37 Hubble, Camron   6.10     0-0    6   0   0  0-0   0   10.1   13  ...
# 6      10 Higgins, Sean   6.38   3-Feb    5   5   0  0-0   0   24.0   33  ...
# 7         29 Leon, Andy   6.48  Jan-00    3   1   0  0-0   0    8.1   12  ...
# 8         32 Yoo, Derek   6.57     0-1    6   1   0  0-0   0   12.1   18  ...
# 9        45 Sheets, Joe   7.71     0-1    5   4   0  0-0   0   16.1   28  ...
# 10      33 Black, Billy   9.35     0-4    5   5   0  0-0   0   17.1   24  ...
# ...

# %%
#Brown
sch = "brown"
brbatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
brfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
brpitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
brbatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in brbatting['GP-GS']]
brbatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in brbatting['GP-GS']]
brbatting.GP=brbatting.GP.replace(month)
brbatting=brbatting.astype({'GP': 'int64'})
brbatting['School'] = 'Brown'
brpitching['School'] = 'Brown'

# %%
#Harvard
sch = "harvard"
harbatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
harfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
harpitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
harbatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in harbatting['GP-GS']]
harbatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in harbatting['GP-GS']]
harbatting.GP=harbatting.GP.replace(month)
harbatting=harbatting.astype({'GP': 'int64'})
harbatting['School'] = 'Harvard'
harpitching['School'] = 'Harvard'

# %%
#Yale
sch = "yale"
ybatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
yfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
ypitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
ybatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in ybatting['GP-GS']]
ybatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in ybatting['GP-GS']]
ybatting.GP=ybatting.GP.replace(month)
ybatting=ybatting.astype({'GP': 'int64'})
ybatting['School'] = 'Yale'
ypitching['School'] = 'Yale'

# %%
sch = "penn"
pnbatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
pnfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
pnpitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
pnbatting.columns = [x.upper() for x in pnbatting.columns]
pnpitching.columns = [x.upper() for x in pnpitching.columns]
pnbatting.columns = [x.upper() for x in pnbatting.columns]
pnpitching.columns = [x.upper() for x in pnpitching.columns]
pnbatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in pnbatting['GP-GS']]
pnbatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in pnbatting['GP-GS']]
pnbatting.GP=pnbatting.GP.replace(month)

pnbatting=pnbatting.astype({'SO GDP': 'string'})
pnbatting['SO'] =  [x.split(" ")[0] for x in pnbatting["SO GDP"]]
pnbatting['GDP'] =  [x.split(" ")[1] for x in pnbatting["SO GDP"]]

pnbatting=pnbatting.astype({'E FLD%': 'string'})
pnbatting['E'] =  [x.split(" ")[0] for x in pnbatting['E FLD%']]
pnbatting['FLD%'] =  [x.split(" ")[1] for x in pnbatting['E FLD%']]
pnbatting=pnbatting.astype({'E': 'int64','FLD%': 'float64'})
pnbatting['FLD%'] = pnbatting['FLD%']/1000 

pnpitching=pnpitching.astype({'HRB/AVG': 'string'})
pnpitching['HR'] =  [x.split(".")[0] for x in pnpitching['HRB/AVG']]
pnpitching['B/AVG'] =  [x.split(".")[1] for x in pnpitching['HRB/AVG']]
pnpitching=pnpitching.astype({'HR': 'int64','B/AVG': 'int64'})
pnpitching['B/AVG'] = pnpitching['B/AVG']/1000 

pnpitching=pnpitching.astype({'BK SFA': 'string'})
pnpitching['BK'] =  [x.split(" ")[0] for x in pnpitching['BK SFA']]
pnpitching['SFA'] =  [x.split(" ")[1] for x in pnpitching['BK SFA']]
pnbatting=pnbatting.astype({'SO': 'int64','GDP': 'int64'})
pnbatting['School'] = 'Penn'
pnpitching['School'] = 'Penn'

# %%
#Princeton
sch = "princeton"
prbatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
prfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
prpitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
prbatting.columns = [x.upper() for x in prbatting.columns]
prpitching.columns = [x.upper() for x in prpitching.columns]
prbatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in prbatting['GP-GS']]
prbatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in prbatting['GP-GS']]
prbatting.GP=prbatting.GP.replace(month)
prbatting=prbatting.astype({'GP': 'int64'})
prbatting['School'] = 'Princeton'
prpitching['School'] = 'Princeton'

# %%
#Dartmouth
sch = "dartmouth"
dmbatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
dmfielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
dmpitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
dmbatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in dmbatting['GP-GS']]
dmbatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in dmbatting['GP-GS']]
dmbatting.GP=dmbatting.GP.replace(month)
dmbatting=dmbatting.astype({'GP': 'int64'})
dmbatting['School'] = 'Dartmouth'
dmpitching['School'] = 'Dartmouth'

# %%
#Cornell
sch = "cornell"
cobatting = pd.read_csv(r'data' + '\\'+sch+r' - batting.csv')
cofielding = pd.read_csv(r'data' + '\\'+sch+r' - fielding.csv')
copitching = pd.read_csv(r'data' + '\\'+sch+r' - pitching.csv')
cobatting['GP'] =  [re.sub(r'([^-]*)-','', str(x)) for x in cobatting['GP-GS']]
cobatting['GS'] =  [re.sub(r'-(.*)','', str(x)) for x in cobatting['GP-GS']]
cobatting.GP=cobatting.GP.replace(month)
cobatting=cobatting.astype({'GP': 'int64'})
cobatting['School'] = 'Cornell'
copitching['School'] = 'Cornell'

# %%
clpitching.rename(columns={ clpitching.columns[0]: "Player" },inplace=True)
copitching.rename(columns={ copitching.columns[0]: "Player" },inplace=True)
harpitching.rename(columns={ harpitching.columns[0]: "Player" },inplace=True)
brpitching.rename(columns={ brpitching.columns[0]: "Player" },inplace=True)
ypitching.rename(columns={ ypitching.columns[0]: "Player" },inplace=True)
prpitching.rename(columns={ prpitching.columns[0]: "Player" },inplace=True)
pnpitching.rename(columns={ pnpitching.columns[0]: "Player" },inplace=True)
dmpitching.rename(columns={ dmpitching.columns[0]: "Player" },inplace=True)

# %%
clbatting.rename(columns={ clbatting.columns[0]: "Player" },inplace=True)
cobatting.rename(columns={ cobatting.columns[0]: "Player" },inplace=True)
harbatting.rename(columns={ harbatting.columns[0]: "Player" },inplace=True)
brbatting.rename(columns={ brbatting.columns[0]: "Player" },inplace=True)
ybatting.rename(columns={ ybatting.columns[0]: "Player" },inplace=True)
prbatting.rename(columns={ prbatting.columns[0]: "Player" },inplace=True)
pnbatting.rename(columns={ pnbatting.columns[0]: "Player" },inplace=True)
dmbatting.rename(columns={ dmbatting.columns[0]: "Player" },inplace=True)

# %%
clpitching["Index"]=clpitching["Player"]
clpitching.set_index('Player',inplace=True)
brpitching["Index"]=brpitching["Player"]
brpitching.set_index('Player',inplace=True)
harpitching["Index"]=harpitching["Player"]
harpitching.set_index('Player',inplace=True)
ypitching["Index"]=ypitching["Player"]
ypitching.set_index('Player',inplace=True)
copitching["Index"]=copitching["Player"]
copitching.set_index('Player',inplace=True)
pnpitching["Index"]=pnpitching["Player"]
pnpitching.set_index('Player',inplace=True)
dmpitching["Index"]=dmpitching["Player"]
dmpitching.set_index('Player',inplace=True)
prpitching["Index"]=prpitching["Player"]
prpitching.set_index('Player',inplace=True)

# %%
clbatting["Index"]=clbatting["Player"]
clbatting.set_index('Player',inplace=True)
brbatting["Index"]=brbatting["Player"]
brbatting.set_index('Player',inplace=True)
harbatting["Index"]=harbatting["Player"]
harbatting.set_index('Player',inplace=True)
ybatting["Index"]=ybatting["Player"]
ybatting.set_index('Player',inplace=True)
cobatting["Index"]=cobatting["Player"]
cobatting.set_index('Player',inplace=True)
pnbatting["Index"]=pnbatting["Player"]
pnbatting.set_index('Player',inplace=True)
dmbatting["Index"]=dmbatting["Player"]
dmbatting.set_index('Player',inplace=True)
prbatting["Index"]=prbatting["Player"]
prbatting.set_index('Player',inplace=True)

# %%
pnbatting.rename(columns = {'HP':'HBP'},inplace=True)
prpitching.rename(columns = {'HBP':'HP'},inplace=True)

# %%
pnbatting.drop(columns=["SO GDP","E FLD%"],inplace = True)
pnpitching.drop(columns=["BK SFA"],inplace = True)

# %%
clbatting["ISO"] = clbatting["SLG%"] - clbatting["AVG"]
brbatting["ISO"] = brbatting["SLG%"] - brbatting["AVG"]
harbatting["ISO"] = harbatting["SLG%"] - harbatting["AVG"]
ybatting["ISO"] = ybatting["SLG%"] - ybatting["AVG"]
cobatting["ISO"] = cobatting["SLG%"] - cobatting["AVG"]
prbatting["ISO"] = prbatting["SLG%"] - prbatting["AVG"]
dmbatting["ISO"] = dmbatting["SLG%"] - dmbatting["AVG"]
pnbatting["ISO"] = pnbatting["SLG%"] - pnbatting["AVG"]

# %%
clbatting["RC"] = clbatting["TB"]*(clbatting["H"] + clbatting["BB"])/(clbatting["AB"]+clbatting["BB"])
brbatting["RC"] = brbatting["TB"]*(brbatting["H"] + brbatting["BB"])/(brbatting["AB"]+brbatting["BB"])
harbatting["RC"] = harbatting["TB"]*(harbatting["H"] + harbatting["BB"])/(harbatting["AB"]+harbatting["BB"])
ybatting["RC"] = (ybatting["TB"]*(ybatting["H"] + ybatting["BB"]))/(ybatting["AB"]+ybatting["BB"])
cobatting["RC"] = cobatting["TB"]*(cobatting["H"] + cobatting["BB"])/(cobatting["AB"]+cobatting["BB"])
prbatting["RC"] = prbatting["TB"]*(prbatting["H"] + prbatting["BB"])/(prbatting["AB"]+prbatting["BB"])
dmbatting["RC"] = dmbatting["TB"]*(dmbatting["H"] + dmbatting["BB"])/(dmbatting["AB"]+dmbatting["BB"])
pnbatting["RC"] = pnbatting["TB"]*(pnbatting["H"] + pnbatting["BB"])/(pnbatting["AB"]+pnbatting["BB"])

# %%
#clbatting["RF"] = (clbatting["PO"] + clbatting["A"])/clbatting["GP"]
#brbatting["RF"] = (brbatting["PO"] + brbatting["A"])/brbatting["GP"]
#harbatting["RF"] = (harbatting["PO"] + harbatting["A"])/harbatting["GP"]
#ybatting["RF"] = (ybatting["PO"] + ybatting["A"])/ybatting["GP"]
#cobatting["rf"] = (cobatting["po"] + cobatting["a"])/cobatting["gp"]
#prbatting["RF"] = (prbatting["PO"] + prbatting["A"])/prbatting["GP"]
#dmbatting["RF"] = (dmbatting["PO"] + dmbatting["A"])/dmbatting["GP"]
#pnbatting["RF"] = (pnbatting["PO"] + pnbatting["A"])/pnbatting["GP"]

# %%
clbatting["BABIP"] = (clbatting["H"]-clbatting["HR"])/(clbatting["AB"]-clbatting["HR"]-clbatting["SO"]+clbatting["SF"])
brbatting["BABIP"] = (brbatting["H"]-brbatting["HR"])/(brbatting["AB"]-brbatting["HR"]-brbatting["SO"]+brbatting["SF"])
harbatting["BABIP"] = (harbatting["H"]-harbatting["HR"])/(harbatting["AB"]-harbatting["HR"]-harbatting["SO"]+harbatting["SF"])
ybatting["BABIP"] = (ybatting["H"]-ybatting["HR"])/(ybatting["AB"]-ybatting["HR"]-ybatting["SO"]+ybatting["SF"])
cobatting["BABIP"] = (cobatting["H"]-cobatting["HR"])/(cobatting["AB"]-cobatting["HR"]-cobatting["SO"]+cobatting["SF"])
prbatting["BABIP"] = (prbatting["H"]-prbatting["HR"])/(prbatting["AB"]-prbatting["HR"]-prbatting["SO"]+prbatting["SF"])
dmbatting["BABIP"] = (dmbatting["H"]-dmbatting["HR"])/(dmbatting["AB"]-dmbatting["HR"]-dmbatting["SO"]+dmbatting["SF"])
pnbatting["BABIP"] = (pnbatting["H"]-pnbatting["HR"])/(pnbatting["AB"]-pnbatting["HR"]-pnbatting["SO"]+pnbatting["SF"])

# %%
lgER = clpitching.loc["Totals","ER"] + brpitching.loc["Totals","ER"] + copitching.loc["Totals","ER"] + harpitching.loc["Totals","ER"] + ypitching.loc["Totals","ER"] + prpitching.loc["Totals","ER"] + dmpitching.loc["Totals","ER"] + pnpitching.loc["Totals","ER"]
lgHR = clpitching.loc["Totals","HR"] + brpitching.loc["Totals","HR"] + copitching.loc["Totals","HR"] + harpitching.loc["Totals","HR"] + ypitching.loc["Totals","HR"] + prpitching.loc["Totals","HR"] + dmpitching.loc["Totals","HR"] + pnpitching.loc["Totals","HR"]
lgBB = clpitching.loc["Totals","BB"] + brpitching.loc["Totals","BB"] + copitching.loc["Totals","BB"] + harpitching.loc["Totals","BB"] + ypitching.loc["Totals","BB"] + prpitching.loc["Totals","BB"] + dmpitching.loc["Totals","BB"] + pnpitching.loc["Totals","BB"]
lgHBP = clpitching.loc["Totals","HP"] + brpitching.loc["Totals","HP"] + copitching.loc["Totals","HP"] + harpitching.loc["Totals","HP"] + ypitching.loc["Totals","HP"] + prpitching.loc["Totals","HP"] + dmpitching.loc["Totals","HP"] + pnpitching.loc["Totals","HP"]
lgK = clpitching.loc["Totals","SO"] + brpitching.loc["Totals","SO"] + copitching.loc["Totals","SO"] + harpitching.loc["Totals","SO"] + ypitching.loc["Totals","SO"] + prpitching.loc["Totals","SO"] + dmpitching.loc["Totals","SO"] + pnpitching.loc["Totals","SO"]
lgIP = clpitching.loc["Totals","IP"] + brpitching.loc["Totals","IP"] + copitching.loc["Totals","IP"] + harpitching.loc["Totals","IP"] + ypitching.loc["Totals","IP"] + prpitching.loc["Totals","IP"] + dmpitching.loc["Totals","IP"] + pnpitching.loc["Totals","IP"]
lgERA = 9*(lgER/lgIP)

# %%
fipC = lgERA -(((13*lgHR)+(3*(lgBB+lgHBP))-(2*lgK))/lgIP)
fipC.dtype
lgFIP = (((13*lgHR)+(3*(lgBB+lgHBP))-(2*lgK))/lgIP) + fipC
fipC
# Out:
# 4.597047845266372

# %%
clpitching.loc["Totals","ER"]
# Out:
# 111

# %%
clpitching["FIP"] = (13*clpitching["HR"]+3*(clpitching["BB"]+clpitching["HP"])-2*(clpitching["SO"]))/clpitching["IP"] + fipC
brpitching["FIP"] = (13*brpitching["HR"]+3*(brpitching["BB"]+brpitching["HP"])-2*(brpitching["SO"]))/brpitching["IP"] + fipC
harpitching["FIP"] = (13*harpitching["HR"]+3*(harpitching["BB"]+harpitching["HP"])-2*(harpitching["SO"]))/harpitching["IP"] + fipC
ypitching["FIP"] = (13*ypitching["HR"]+3*(ypitching["BB"]+ypitching["HP"])-2*(ypitching["SO"]))/ypitching["IP"] + fipC
copitching["FIP"] = (13*copitching["HR"]+3*(copitching["BB"]+copitching["HP"])-2*(copitching["SO"]))/copitching["IP"] + fipC
prpitching["FIP"] = (13*prpitching["HR"]+3*(prpitching["BB"]+prpitching["HP"])-2*(prpitching["SO"]))/prpitching["IP"] + fipC
dmpitching["FIP"] = (13*dmpitching["HR"]+3*(dmpitching["BB"]+dmpitching["HP"])-2*(dmpitching["SO"]))/dmpitching["IP"] + fipC
pnpitching["FIP"] = (13*pnpitching["HR"]+3*(pnpitching["BB"]+pnpitching["HP"])-2*(pnpitching["SO"]))/pnpitching["IP"] + fipC

# %%
copitching.iloc[-2]
# Out:
# ERA          10.41
# W-L         11-Mar
# APP             57
# GS              14
# CG               0
# SHO              0
# SV               1
# IP           119.1
# H              160
# R              172
# ER             138
# BB             101
# SO              87
# 2B              30
# 3B               7
# HR              17
# B/AVG        0.323
# WP              34
# HP              38
# BK               2
# SFA             11
# SHA              9
# School     Cornell
# Index       Totals
# FIP       8.492934
# Name: Totals, dtype: object

# %%
cobatting.columns
# Out:
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
#        'BB', 'HBP', 'SO', 'GDP', 'OB%', 'SF', 'SH', 'SB-ATT', 'PO', 'A', 'E',
#        'FLD%', 'GP', 'GS', 'School', 'Index', 'ISO', 'RC', 'BABIP'],
#       dtype='object')

# %%
clpitching["K/9"] = 9*clpitching["SO"]/clpitching["IP"]
brpitching["K/9"] = 9*brpitching["SO"]/brpitching["IP"]
harpitching["K/9"] = 9*harpitching["SO"]/harpitching["IP"]
ypitching["K/9"] = 9*ypitching["SO"]/ypitching["IP"]
copitching["K/9"] = 9*copitching["SO"]/copitching["IP"]
prpitching["K/9"] = 9*prpitching["SO"]/prpitching["IP"]
dmpitching["K/9"] = 9*dmpitching["SO"]/dmpitching["IP"]
pnpitching["K/9"] = 9*pnpitching["SO"]/pnpitching["IP"]

# %%
clpitching["BB/9"] = 9*clpitching["BB"]/clpitching["IP"]
brpitching["BB/9"] = 9*brpitching["BB"]/brpitching["IP"]
harpitching["BB/9"] = 9*harpitching["BB"]/harpitching["IP"]
ypitching["BB/9"] = 9*ypitching["BB"]/ypitching["IP"]
copitching["BB/9"] = 9*copitching["BB"]/copitching["IP"]
prpitching["BB/9"] = 9*prpitching["BB"]/prpitching["IP"]
dmpitching["BB/9"] = 9*dmpitching["BB"]/dmpitching["IP"]
pnpitching["BB/9"] = 9*pnpitching["BB"]/pnpitching["IP"]

# %%
clpitching["K/BB"] = clpitching["K/9"]/clpitching["BB/9"]
brpitching["K/BB"] = brpitching["K/9"]/brpitching["BB/9"]
harpitching["K/BB"] = harpitching["K/9"]/harpitching["BB/9"]
ypitching["K/BB"] = ypitching["K/9"]/ypitching["BB/9"]
copitching["K/BB"] = copitching["K/9"]/copitching["BB/9"]
prpitching["K/BB"] = prpitching["K/9"]/prpitching["BB/9"]
dmpitching["K/BB"] = dmpitching["K/9"]/dmpitching["BB/9"]
pnpitching["K/BB"] = pnpitching["K/9"]/pnpitching["BB/9"]

# %%
clbatting["PA"]=clbatting["AB"]+clbatting["BB"]+clbatting["HBP"]+clbatting["SH"]+clbatting["SF"]
brbatting["PA"]=brbatting["AB"]+brbatting["BB"]+brbatting["HBP"]+brbatting["SH"]+brbatting["SF"]
harbatting["PA"]=harbatting["AB"]+harbatting["BB"]+harbatting["HBP"]+harbatting["SH"]+harbatting["SF"]
ybatting["PA"]=ybatting["AB"]+ybatting["BB"]+ybatting["HBP"]+ybatting["SH"]+ybatting["SF"]
cobatting["PA"]=cobatting["AB"]+cobatting["BB"]+cobatting["HBP"]+cobatting["SH"]+cobatting["SF"]
prbatting["PA"]=prbatting["AB"]+prbatting["BB"]+prbatting["HBP"]+prbatting["SH"]+prbatting["SF"]
dmbatting["PA"]=dmbatting["AB"]+dmbatting["BB"]+dmbatting["HBP"]+dmbatting["SH"]+dmbatting["SF"]
pnbatting["PA"]=pnbatting["AB"]+pnbatting["BB"]+pnbatting["HBP"]+pnbatting["SH"]+pnbatting["SF"]

# %%
clbatting["K%"] = clbatting["SO"]/clbatting["PA"]
brbatting["K%"] = brbatting["SO"]/brbatting["PA"]
harbatting["K%"] = harbatting["SO"]/harbatting["PA"]
ybatting["K%"] = ybatting["SO"]/ybatting["PA"]
cobatting["K%"] = cobatting["SO"]/cobatting["PA"]
prbatting["K%"] = prbatting["SO"]/prbatting["PA"]
dmbatting["K%"] = dmbatting["SO"]/dmbatting["PA"]
pnbatting["K%"] = pnbatting["SO"]/pnbatting["PA"]

# %%
clbatting["BB%"] = clbatting["BB"]/clbatting["PA"]
brbatting["BB%"] = brbatting["BB"]/brbatting["PA"]
harbatting["BB%"] = harbatting["BB"]/harbatting["PA"]
ybatting["BB%"] = ybatting["BB"]/ybatting["PA"]
cobatting["BB%"] = cobatting["BB"]/cobatting["PA"]
prbatting["BB%"] = prbatting["BB"]/prbatting["PA"]
dmbatting["BB%"] = dmbatting["BB"]/dmbatting["PA"]
pnbatting["BB%"] = pnbatting["BB"]/pnbatting["PA"]

# %%
clbatting["BABIP-AVG"] = clbatting["BABIP"]-clbatting["AVG"]
brbatting["BABIP-AVG"] = brbatting["BABIP"]-brbatting["AVG"]
harbatting["BABIP-AVG"] = harbatting["BABIP"]-harbatting["AVG"]
ybatting["BABIP-AVG"] = ybatting["BABIP"]-ybatting["AVG"]
cobatting["BABIP-AVG"] = cobatting["BABIP"]-cobatting["AVG"]
prbatting["BABIP-AVG"] = prbatting["BABIP"]-prbatting["AVG"]
dmbatting["BABIP-AVG"] = dmbatting["BABIP"]-dmbatting["AVG"]
pnbatting["BABIP-AVG"] = pnbatting["BABIP"]-pnbatting["AVG"]

# %%
clpitching["ERA-FIP"] = clpitching["ERA"]-clpitching["FIP"]
brpitching["ERA-FIP"] = brpitching["ERA"]-brpitching["FIP"]
harpitching["ERA-FIP"] = harpitching["ERA"]-harpitching["FIP"]
ypitching["ERA-FIP"] = ypitching["ERA"]-ypitching["FIP"]
copitching["ERA-FIP"] = copitching["ERA"]-copitching["FIP"]
prpitching["ERA-FIP"] = prpitching["ERA"]-prpitching["FIP"]
dmpitching["ERA-FIP"] = dmpitching["ERA"]-dmpitching["FIP"]
pnpitching["ERA-FIP"] = pnpitching["ERA"]-pnpitching["FIP"]

# %%
clpitching["FIP-lgFIP"] = clpitching["FIP"]-lgFIP
brpitching["FIP-lgFIP"] = brpitching["FIP"]-lgFIP
harpitching["FIP-lgFIP"] = harpitching["FIP"]-lgFIP
ypitching["FIP-lgFIP"] = ypitching["FIP"]-lgFIP
copitching["FIP-lgFIP"] = copitching["FIP"]-lgFIP
prpitching["FIP-lgFIP"] = prpitching["FIP"]-lgFIP
dmpitching["FIP-lgFIP"] = dmpitching["FIP"]-lgFIP
pnpitching["FIP-lgFIP"] = pnpitching["FIP"]-lgFIP

# %%
clbatting=clbatting.sort_values(by=["BABIP"],ascending=False)
clbattingq=clbatting[clbatting["PA"]>=30]

# %%
brbatting=brbatting.sort_values(by=["BABIP"],ascending=False)
brbattingq=brbatting[brbatting["PA"]>=30]

# %%
cobatting=cobatting.sort_values(by=["BABIP"],ascending=False)
cobattingq=cobatting[cobatting["PA"]>=30]

# %%
ybatting=ybatting.sort_values(by=["BABIP"],ascending=False)
ybattingq=ybatting[ybatting["PA"]>=30]

# %%
harbatting=harbatting.sort_values(by=["BABIP"],ascending=False)
harbattingq=harbatting[harbatting["PA"]>=30]

# %%
dmbatting=dmbatting.sort_values(by=["BABIP"],ascending=False)
dmbattingq = dmbatting[dmbatting["PA"]>=30]

# %%
pnbatting=pnbatting.sort_values(by=["BABIP"],ascending=False)
pnbattingq=pnbatting[pnbatting["PA"]>=30]

# %%
prbatting=prbatting.sort_values(by=["BABIP"],ascending=False)
prbattingq = prbatting[prbatting["PA"]>=30]

# %%
clpitching=clpitching.sort_values(by=["ERA-FIP"],ascending=False)
clpitchingq=clpitching[clpitching["IP"]>=10]

# %%
copitching=copitching.sort_values(by=["ERA-FIP"],ascending=False)
copitchingq=copitching[copitching["IP"]>=10]

# %%
brpitching=brpitching.sort_values(by=["ERA-FIP"],ascending=False)
brpitchingq=brpitching[brpitching["IP"]>=10]

# %%
copitching.columns
# Out:
# Index(['ERA', 'W-L', 'APP', 'GS', 'CG', 'SHO', 'SV', 'IP', 'H', 'R', 'ER',
#        'BB', 'SO', '2B', '3B', 'HR', 'B/AVG', 'WP', 'HP', 'BK', 'SFA', 'SHA',
#        'School', 'Index', 'FIP', 'K/9', 'BB/9', 'K/BB', 'ERA-FIP',
#        'FIP-lgFIP'],
#       dtype='object')

# %%
harpitching=harpitching.sort_values(by=["ERA-FIP"],ascending=False)
harpitchingq=harpitching[harpitching["IP"]>=10]

# %%
ypitching=ypitching.sort_values(by=["FIP"],ascending=False)
ypitchingq=ypitching[ypitching["IP"]>=10]

# %%
dmpitching=dmpitching.sort_values(by=["ERA-FIP"],ascending=False)
dmpitchingq=dmpitching[dmpitching["IP"]>=10]

# %%
pnpitching=pnpitching.sort_values(by=["ERA-FIP"],ascending=False)
pnpitchingq=pnpitching[pnpitching["IP"]>=10]

# %%
pnpitching
# Out:
#                     ERA     W-L  APP  GS  CG    SHO  SV     IP    H    R  ...  \
# Player                                                                    ...
# Sarti, Edward     12.27  Feb-00    7   0   0    0/0   0    7.1   12   10  ...
# Beal, Nate        18.00     0-0    2   0   0    0/0   0    1.0    0    2  ...
# Millikan, Noah     9.45   1-Jan    4   1   0    0/0   0    6.2    5    7  ...
# Heintz, Danny      6.10     0-1    9   0   0    0/0   0   10.1    5    8  ...
# Opponents          6.37  13-Jul   21  21   0  1-Jan   2  178.0  228  149  ...
# Eaise, Kevin       4.94   1-Jan    5   5   0    0/0   0   27.1   30   15  ...
# Tobin, Will       11.57     0-0    2   2   0    0/0   0    4.2    6    6  ...
# Dromboski, Ryan    9.00     0-0    3   0   0    0/0   0    2.0    3    2  ...
# Zaffiro, Cole      3.44  Feb-00    6   3   0    0/0   0   18.1   15    7  ...
# Coady, Owen        2.70  Mar-00    6   2   0    0/0   0   26.2   17    8  ...
# ...

# %%
prpitching=prpitching.sort_values(by=["ERA-FIP"],ascending=False)
prpitchingq=prpitching[prpitching["IP"]>=10]

# %%
prpitchingq.sort_values(by=["K/9"],ascending=False)
# Out:
#                      ERA     W-L  APP-GS  CG  SHO  SV     IP    H    R   ER  \
# Player
# Opponents           5.01    16-2   18-18   0  0/0   5  160.0  177  104   89
# Emus, Jackson       5.14     0-3   5-May   0  0/0   0   28.0   27   17   16
# Jarvis, Patrick     9.53     0-0  Jun-00   0  0/0   1   11.1   11   13   12
# Chmielewski, Tom    9.00   3-Jan   5-May   0  0/0   0   23.0   41   29   23
# Totals              7.73  16-Feb   18-18   0  0/0   1  149.0  194  148  128
# Hoefer, Eric        7.53   1-Jan  Jun-00   0  0/0   0   14.1   22   15   12
# Rabin, Reece       13.09     0-3   2-May   0  0/0   0   11.0   21   21   16
# D'Alessio, Andrew   7.14     0-3   5-May   0  0/0   0   29.0   32   26   23
#
#                    ...  SFA  SHA     School              Index       FIP  \
# Player             ...
# Opponents          ...    7    4  Princeton          Opponents  5.672048
# Emus, Jackson      ...    0    1  Princeton      Emus, Jackson  6.311334
# ...

# %%
clbatting.to_csv("columbia-batting-updated.csv")
clpitching.to_csv("columbia-pitching-updated.csv")

# %%
brbatting.to_csv("brown-batting-updated.csv")
brpitching.to_csv("brown-pitching-updated.csv")

# %%
harbatting.to_csv("harvard-batting-updated.csv")
harpitching.to_csv("harvard-pitching-updated.csv")

# %%
ybatting.to_csv("yale-batting-updated.csv")
ypitching.to_csv("yale-pitching-updated.csv")

# %%
cobatting.to_csv("cornell-batting-fixed.csv")
copitching.to_csv("cornell-pitching-fixed.csv")

# %%
prbatting.to_csv("princeton-batting-updated.csv")
prpitching.to_csv("princeton-pitching-updated.csv")

# %%
dmbatting.to_csv("dartmouth-batting-updated.csv")
dmpitching.to_csv("dartmouth-pitching-updated.csv")

# %%
pnbatting.to_csv("penn-batting-fixed.csv")
pnpitching.to_csv("penn-pitching-fixed.csv")

# %%
pitchers = pd.concat([clpitching,copitching,brpitching,harpitching,ypitching,pnpitching,prpitching,dmpitching])
batters = pd.concat([clbatting,cobatting,brbatting,harbatting,ybatting,pnbatting,prbatting,dmbatting])

# %%
batters.to_csv("batting-updated.csv")
pitchers.to_csv("pitching-updated.csv")
#batters.sort_values(by=["BABIP-AVG"])

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)
#prbatting

# %%
clpitchingq[clpitchingq["ERA-FIP"]>0]
# Out:
#                       ERA     W-L  APP  GS  CG  SHO  SV     IP    H    R   ER  \
# Player
# 32 Yoo, Derek        6.57     0-1    6   1   0  0-0   0   12.1   18   13    9
# 45 Sheets, Joe       7.71     0-1    5   4   0  0-0   0   16.1   28   15   14
# 33 Black, Billy      9.35     0-4    5   5   0  0-0   0   17.1   24   23   18
# 9 Madrigal, Brandon  9.53     0-0    6   0   0  0-0   0   11.1   14   14   12
# 10 Higgins, Sean     6.38   3-Feb    5   5   0  0-0   0   24.0   33   17   17
# Totals               6.32  12-Jul   67  19   0    0   2  158.0  206  128  111
#
#                      BB   SO  2B  3B  HR  B/AVG  WP  HP  BK  SFA  SHA  \
# Player
# 32 Yoo, Derek         6   11   8   0   0  0.327   1   0   0    2    0
# 45 Sheets, Joe        6   12   1   1   2  0.378   0   1   0    0    0
# 33 Black, Billy      12   11   5   0   3  0.333   3   1   1    2    2
# 9 Madrigal, Brandon   8    6   3   0   1  0.350   4   6   0    1    3
# ...

# %%
brpitchingq[brpitchingq["ERA-FIP"]>0]
# Out:
#                       ERA     W-L  APP  GS  CG  SHO  SV     IP    H   R  ER  \
# Player
# 18 Gottam, Santhosh  9.17   3-Jan    5   4   0  0-0   0   17.2   32  19  18
# 9 Fogell, Zach       8.76     0-3    5   3   0  0-0   0   12.1   20  15  12
# Totals               5.58  11-Apr   49  15   1    0   2  122.2  133  89  76
#
#                      BB   SO  2B  3B  HR  B/AVG  WP  HP  BK  SFA  SHA School  \
# Player
# 18 Gottam, Santhosh   3   14   5   1   2  0.395   3   2   0    2    2  Brown
# 9 Fogell, Zach        8   16   4   0   3  0.364   4   3   0    1    1  Brown
# Totals               55  116  29   5   8  0.274  27  15   1    5    8  Brown
#
#                                    Index       FIP        K/9      BB/9  \
# Player
# 18 Gottam, Santhosh  18 Gottam, Santhosh  5.352862   7.325581  1.569767
# 9 Fogell, Zach            9 Fogell, Zach  7.902833  11.900826  5.950413
# Totals                            Totals  5.268079   8.543372  4.050736
#
# ...

# %%
prpitchingq[prpitchingq["ERA-FIP"]>0]
# Out:
#                     ERA     W-L  APP-GS  CG  SHO  SV     IP    H    R   ER  \
# Player
# Chmielewski, Tom   9.00   3-Jan   5-May   0  0/0   0   23.0   41   29   23
# Rabin, Reece      13.09     0-3   2-May   0  0/0   0   11.0   21   21   16
# Jarvis, Patrick    9.53     0-0  Jun-00   0  0/0   1   11.1   11   13   12
# Totals             7.73  16-Feb   18-18   0  0/0   1  149.0  194  148  128
#
#                   BB   SO  2B  3B  HR   AB  B/AVG  WP  HP  BK  SFA  SHA  \
# Player
# Chmielewski, Tom   8   18   9   0   2  109  0.376   2   2   0    4    3
# Rabin, Reece       7    6   6   0   3   53  0.396   1   3   0    0    3
# Jarvis, Patrick   10   12   3   0   2   47  0.234   2   5   0    0    0
# Totals            78  103  36   3  26  620  0.313  13  25   3   11   13
#
#                      School             Index       FIP       K/9      BB/9  \
# Player
# Chmielewski, Tom  Princeton  Chmielewski, Tom  5.466613  7.043478  3.130435
# ...

# %%
print(len(prpitchingq.columns))
print(len(clpitchingq.columns))
print(len(copitchingq.columns))
print(len(brpitchingq.columns))
print(len(ypitchingq.columns))
print(len(harpitchingq.columns))
print(len(pnpitchingq.columns))
print(len(dmpitchingq.columns))
# Out:
# 30
# 30
# 30
# 30
# 30
# 30
# 31
# 30

# %%
print(len(prbattingq.columns))
print(len(clbattingq.columns))
print(len(cobattingq.columns))
print(len(brbattingq.columns))
print(len(ybattingq.columns))
print(len(harbattingq.columns))
print(len(pnbattingq.columns))
print(len(dmbattingq.columns))
# Out:
# 34
# 34
# 34
# 34
# 34
# 34
# 34
# 34

# %%
print(cobattingq.columns)
print(clbattingq.columns)
# Out:
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
#        'BB', 'HBP', 'SO', 'GDP', 'OB%', 'SF', 'SH', 'SB-ATT', 'PO', 'A', 'E',
#        'FLD%', 'GP', 'GS', 'School', 'Index', 'ISO', 'RC', 'BABIP', 'PA', 'K%',
#        'BB%', 'BABIP-AVG'],
#       dtype='object')
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
#        'BB', 'HBP', 'SO', 'GDP', 'OB%', 'SF', 'SH', 'SB-ATT', 'PO', 'A', 'E',
#        'FLD%', 'GP', 'GS', 'School', 'Index', 'ISO', 'RC', 'BABIP', 'PA', 'K%',
#        'BB%', 'BABIP-AVG'],
#       dtype='object')

# %% [markdown]
# clbattings = clbattingq.drop(index=["Totals","Opponents"],axis=0,inplace=True)
# clbattings = clbattings.drop("Opponents",axis=0,inplace=True)
# brbattings = brbattingq.drop("Totals",axis=0,inplace=True)
# brbattings = brbattings.drop("Opponents",axis=0,inplace=True)
# cobattings = cobattingq.drop("Totals",axis=0,inplace=True)
# cobattings = cobattings.drop("Opponents",axis=0,inplace=True)
# harbattings = harbattingq.drop("Totals",axis=0,inplace=True)
# harbattings = harbattings.drop("Opponents",axis=0,inplace=True)
# ybattings = ybattingq.drop("Totals",axis=0,inplace=True)
# ybattings = ybattings.drop("Opponents",axis=0,inplace=True)
# prbattings = prbattingq.drop("Totals",axis=0,inplace=True)
# prbattings = prbattings.drop("Opponents",axis=0,inplace=True)
# pnbattings = pnbattingq.drop("Totals",axis=0,inplace=True)
# pnbattings = pnbattings.drop("",axis=0,inplace=True)
# dmbattings = dmbattingq.drop("Totals",axis=0,inplace=True)
# dmbattings = dmbattings.drop("Totals",axis=0,inplace=True)

# %%
qbatters = pd.concat([clbattingq,cobattingq,brbattingq,harbattingq,ybattingq,pnbattingq,prbattingq,dmbattingq])

# %%
qbatters.sort_values(by=["BABIP-AVG"],ascending=False)
# Out:
#                         AVG   GP-GS   AB    R    H  2B  3B  HR  RBI   TB  \
# Player
# 40 Solomon, Joshua    0.258   18-18   66   10   17   3   0   3    6   29
# 8 Baldwin, Hunter     0.225   15-14   40    5    9   3   0   0    6   12
# 40 Waugh, Nathan      0.308   6-Oct   26    7    8   1   1   2    3   17
# Polo, Nate            0.273   8-Aug   22    8    6   1   0   0    4    7
# Kelly, Jordan         0.288   17-15   52   12   15   1   2   1    5   23
# Marasheski, Eric      0.240   6-Nov   25    6    6   0   0   1    3    9
# 22 Davis, Jakobi      0.208   14-13   48   10   10   1   1   0    8   13
# 3 Ross, Ryan          0.280   7-Oct   25    6    7   2   2   2    9   19
# 30 Hollerbach, Joe    0.345   14-14   58    7   20   5   1   3    9   36
# Abello, Carlos        0.261   17-14   46    4   12   2   0   0    3   14
# 7 Morphew, Derian     0.242   15-15   62    6   15   2   1   1    4   22
# 2 Barnhorst, Matt     0.278  10-Nov   36   10   10   3   0   2    3   19
# ...

# %%
qpitchers = pd.concat([clpitchingq,copitchingq,brpitchingq,harpitchingq,ypitchingq,pnpitchingq,prpitchingq,dmpitchingq])

# %%
qpitchers.sort_values(by=["FIP"],ascending=True).head(20)
# Out:
#                       ERA     W-L   APP    GS  CG     SHO  SV     IP    H   R  \
# Player
# 23 Driver, Jay       0.00     0-0   7.0   0.0   0     0-2   3   12.0    4   0
# Coady, Owen          2.70  Mar-00   6.0   2.0   0     0/0   0   26.2   17   8
# Zaffiro, Cole        3.44  Feb-00   6.0   3.0   0     0/0   0   18.1   15   7
# Opponents            3.37   4-Nov  57.0  15.0   1       2   7  131.0  111  57
# 13 McDonough, Tobey  2.10   1-Feb   5.0   5.0   1     0-0   0   30.0   18   8
# 21 Easterly, Reid    3.12   2-Jan   9.0   0.0   0     0-1   2   17.1   16   7
# 32 Yoo, Derek        6.57     0-1   6.0   1.0   0     0-0   0   12.1   18  13
# 15 Skinner, Nathan   3.00   1-Feb   4.0   4.0   1  Jan-00   0   24.0   24   8
# 30 Narottam, Uday    1.46  Jan-00   6.0   0.0   0     0-0   1   12.1    9   4
# Eaise, Kevin         4.94   1-Jan   5.0   5.0   0     0/0   0   27.1   30  15
# 3 Olsen, Bobby       3.10     0-1   6.0   3.0   0     0-0   0   29.0   25  14
# ...

# %%
qbatters.to_csv("qualified-batting.csv")
qpitchers.to_csv("qualified-pitching.csv")

# %%
print(cobattingq.columns)
print(clbattingq.columns)
print(cobattingq.columns)
print(clbattingq.columns)
print(cobattingq.columns)
print(clbattingq.columns)
print(cobattingq.columns)
print(clbattingq.columns)
# Out:
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
#        'BB', 'HBP', 'SO', 'GDP', 'OB%', 'SF', 'SH', 'SB-ATT', 'PO', 'A', 'E',
#        'FLD%', 'GP', 'GS', 'School', 'Index', 'ISO', 'RC', 'BABIP', 'PA', 'K%',
#        'BB%', 'BABIP-AVG'],
#       dtype='object')
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
#        'BB', 'HBP', 'SO', 'GDP', 'OB%', 'SF', 'SH', 'SB-ATT', 'PO', 'A', 'E',
#        'FLD%', 'GP', 'GS', 'School', 'Index', 'ISO', 'RC', 'BABIP', 'PA', 'K%',
#        'BB%', 'BABIP-AVG'],
#       dtype='object')
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
#        'BB', 'HBP', 'SO', 'GDP', 'OB%', 'SF', 'SH', 'SB-ATT', 'PO', 'A', 'E',
#        'FLD%', 'GP', 'GS', 'School', 'Index', 'ISO', 'RC', 'BABIP', 'PA', 'K%',
#        'BB%', 'BABIP-AVG'],
#       dtype='object')
# Index(['AVG', 'GP-GS', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'TB', 'SLG%',
# ...

# %%
list(set(prpitchingq.columns) - set(clpitchingq.columns))
# Out:
# ['APP-GS', 'AB']

# %%
import seaborn as sns
qpitcherspos = qpitchers[qpitchers["ERA-FIP"]>=0].sort_values(by=["ERA-FIP"],ascending=False)
qpitcherspos.drop(index=["Totals","Opponents"],axis=0,inplace=True)
bar = sns.barplot(y=qpitcherspos.index,x=qpitcherspos["ERA-FIP"])
figure=bar.get_figure()
#figure.savefig("fip-era.pdf")

# %%
qbatterspos = qbatters.sort_values(by=["BABIP-AVG"],ascending=False)
qbatterspos.drop(qbatterspos.index[5:],inplace=True)
qbatterspos

sns.set(rc={'figure.figsize':(11.7,8.27)})
bar2 = sns.barplot(y=qbatterspos.index,x=qbatterspos["BABIP-AVG"])
#figure=bar.get_figure("babip-avg.pdf")

# %%
qbatterspos = qbatters.sort_values(by=["BABIP"],ascending=False)
qbatterstop5 = qbatterspos.drop(qbatterspos.index[10:])
qbatterspos
#bar2.set(xlim=(0, .55))
sns.set(rc={'figure.figsize':(11.7,8.27)})
bar2 = sns.barplot(y=qbatterstop5.index,x=qbatterstop5["BABIP"])
figure2=bar2.get_figure()
#figure2.savefig("babip.pdf")

# %%
qbattersops = pd.read_csv("qualifiedbattersops.csv")
qbattersops= qbattersops.astype({'PA': 'int64'})
bar3 = sns.scatterplot(y=qbattersops["OPS+"],x=qbattersops["PA"])
bar3.set(xlim=(15, 120))
figure3=bar3.get_figure()
#figure3.savefig("ops-pa.pdf")
#figure=bar.get_figure("babip-avg.pdf")
qbatters.sort_values(by="BABIP",ascending=False)
# Out:
#                         AVG   GP-GS   AB    R    H  2B  3B  HR  RBI   TB  \
# Player
# Emus, Jackson         0.419   8-Sep   31    3   13   2   0   0    7   15
# 27 Snopek, Chris      0.397   18-18   68   12   27   4   0   1   12   34
# 30 Hollerbach, Joe    0.345   14-14   58    7   20   5   1   3    9   36
# 40 Waugh, Nathan      0.308   6-Oct   26    7    8   1   1   2    3   17
# Henseler, Wyatt       0.438   21-21   80   21   35   6   0   7   27   62
# Kelly, Jordan         0.288   17-15   52   12   15   1   2   1    5   23
# 40 Solomon, Joshua    0.258   18-18   66   10   17   3   0   3    6   29
# Lewis, Nadir          0.422   18-18   64   18   27   5   1   7   22   55
# Polo, Nate            0.273   8-Aug   22    8    6   1   0   0    4    7
# Wilson, Asa           0.333   9-Oct   36    9   12   4   0   1    6   19
# 3 Ross, Ryan          0.280   7-Oct   25    6    7   2   2   2    9   19
# 20 Brasher, Nathan    0.311   15-15   61   10   19   1   1   1    7   25
# ...

# %%
qbatters.sort_values(by=["BABIP-AVG"],ascending=False)
# Out:
#                         AVG   GP-GS   AB    R    H  2B  3B  HR  RBI   TB  \
# Player
# 40 Solomon, Joshua    0.258   18-18   66   10   17   3   0   3    6   29
# 8 Baldwin, Hunter     0.225   15-14   40    5    9   3   0   0    6   12
# 40 Waugh, Nathan      0.308   6-Oct   26    7    8   1   1   2    3   17
# Polo, Nate            0.273   8-Aug   22    8    6   1   0   0    4    7
# Kelly, Jordan         0.288   17-15   52   12   15   1   2   1    5   23
# Marasheski, Eric      0.240   6-Nov   25    6    6   0   0   1    3    9
# 22 Davis, Jakobi      0.208   14-13   48   10   10   1   1   0    8   13
# 3 Ross, Ryan          0.280   7-Oct   25    6    7   2   2   2    9   19
# 30 Hollerbach, Joe    0.345   14-14   58    7   20   5   1   3    9   36
# Abello, Carlos        0.261   17-14   46    4   12   2   0   0    3   14
# 7 Morphew, Derian     0.242   15-15   62    6   15   2   1   1    4   22
# 2 Barnhorst, Matt     0.278  10-Nov   36   10   10   3   0   2    3   19
# ...

# %%
scatter = sns.scatterplot(x=qpitchers["K/9"], y=qpitchers[""])

# %%
qpitchers.sort_values(by="BB/9",ascending=True)
# Out:
#                        ERA     W-L   APP    GS  CG     SHO  SV     IP    H  \
# Player
# 22 Kelley, Mick       3.92  Jan-00   8.0   0.0   0     0-1   2   20.2   22
# 15 Skinner, Nathan    3.00   1-Feb   4.0   4.0   1  Jan-00   0   24.0   24
# 18 Gottam, Santhosh   9.17   3-Jan   5.0   4.0   0     0-0   0   17.2   32
# 21 Easterly, Reid     3.12   2-Jan   9.0   0.0   0     0-1   2   17.1   16
# 14 Sarcone, Trystan   6.75   1-Feb   4.0   4.0   0     0-0   0   18.2   23
# 29 Metzger, Jack      4.76     0-0   7.0   0.0   0     0-0   2   17.0   15
# 23 Driver, Jay        0.00     0-0   7.0   0.0   0     0-2   3   12.0    4
# 13 McDonough, Tobey   2.10   1-Feb   5.0   5.0   1     0-0   0   30.0   18
# 3 Olsen, Bobby        3.10     0-1   6.0   3.0   0     0-0   0   29.0   25
# 27 May, Saajan        4.50  Jan-00   5.0   0.0   0     0-0   1   18.0   20
# Eaise, Kevin          4.94   1-Jan   5.0   5.0   0     0/0   0   27.1   30
# ...

# %%
pnpitching
# Out:
#                     ERA     W-L  APP  GS  CG    SHO  SV     IP    H    R   ER  \
# Player
# Sarti, Edward     12.27  Feb-00    7   0   0    0/0   0    7.1   12   10   10
# Beal, Nate        18.00     0-0    2   0   0    0/0   0    1.0    0    2    2
# Millikan, Noah     9.45   1-Jan    4   1   0    0/0   0    6.2    5    7    7
# Heintz, Danny      6.10     0-1    9   0   0    0/0   0   10.1    5    8    7
# Opponents          6.37  13-Jul   21  21   0  1-Jan   2  178.0  228  149  126
# Eaise, Kevin       4.94   1-Jan    5   5   0    0/0   0   27.1   30   15   15
# Tobin, Will       11.57     0-0    2   2   0    0/0   0    4.2    6    6    6
# Dromboski, Ryan    9.00     0-0    3   0   0    0/0   0    2.0    3    2    2
# Zaffiro, Cole      3.44  Feb-00    6   3   0    0/0   0   18.1   15    7    7
# Coady, Owen        2.70  Mar-00    6   2   0    0/0   0   26.2   17    8    8
# Totals             4.91    13-7   21  21   0    0/0   3  177.2  154  105   97
# ...

# %%
qpitcherspos.sort_values(by="ERA-FIP",ascending=False)
# Out:
#                        ERA    W-L  APP   GS  CG  SHO  SV    IP   H   R  ER  \
# Player
# 34 Baker, Von        14.11    0-2  6.0  2.0   0  0-0   0  14.2  17  24  23
# 5 Murray, Justin     10.29  3-Jan  5.0  5.0   0  0-0   0  21.0  32  24  24
# 18 Gottam, Santhosh   9.17  3-Jan  5.0  4.0   0  0-0   0  17.2  32  19  18
# Chmielewski, Tom      9.00  3-Jan  NaN  NaN   0  0/0   0  23.0  41  29  23
# Rabin, Reece         13.09    0-3  NaN  NaN   0  0/0   0  11.0  21  21  16
# 28 Edwards, Spencer  11.45  4-Jan  5.0  5.0   0  0-0   0  22.0  26  33  28
# 32 Yoo, Derek         6.57    0-1  6.0  1.0   0  0-0   0  12.1  18  13   9
# 35 Cortland, Tyler    9.00    0-2  5.0  3.0   0  0-0   0  15.0  23  20  15
# 21 Zinn, Jaren        7.32  1-Feb  5.0  5.0   0  0-0   0  19.2  19  17  16
# 45 Sheets, Joe        7.71    0-1  5.0  4.0   0  0-0   0  16.1  28  15  14
# 14 Sarcone, Trystan   6.75  1-Feb  4.0  4.0   0  0-0   0  18.2  23  15  14
# ...

# %%
len(qpitcherspos)
# Out:
# 22

# %%
qpitchers
# Out:
#                        ERA     W-L   APP    GS  CG     SHO  SV     IP    H  \
# Player
# 32 Yoo, Derek         6.57     0-1   6.0   1.0   0     0-0   0   12.1   18
# 45 Sheets, Joe        7.71     0-1   5.0   4.0   0     0-0   0   16.1   28
# 33 Black, Billy       9.35     0-4   5.0   5.0   0     0-0   0   17.1   24
# 9 Madrigal, Brandon   9.53     0-0   6.0   0.0   0     0-0   0   11.1   14
# 10 Higgins, Sean      6.38   3-Feb   5.0   5.0   0     0-0   0   24.0   33
# Totals                6.32  12-Jul  67.0  19.0   0       0   2  158.0  206
# Opponents             5.23   7-Dec  68.0  19.0   0       1   7  166.3  160
# 27 May, Saajan        4.50  Jan-00   5.0   0.0   0     0-0   1   18.0   20
# 37 Hubble, Camron     6.10     0-0   6.0   0.0   0     0-0   0   10.1   13
# 28 Ogden, JD          4.20     0-2   7.0   1.0   0     0-0   1   15.0   15
# 34 Baker, Von        14.11     0-2   6.0   2.0   0     0-0   0   14.2   17
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
qpitchersdropped=qpitchers.drop(index=["Totals","Opponents"],axis=0)
bar4 = sns.scatterplot(y=qpitchersdropped["B/AVG"],x=qpitchersdropped["K/9"])
bar4.set(xlim=(0, 16))
bar4.set(ylim=(0.05,.45))
bar4.invert_yaxis()
figure4=bar4.get_figure()
#figure4.savefig("k9bavg.pdf")

# %%
qpitchersdropped.sort_values(by="B/AVG",ascending=True)
# Out:
#                        ERA     W-L  APP   GS  CG     SHO  SV    IP   H   R  \
# Player
# 23 Driver, Jay        0.00     0-0  7.0  0.0   0     0-2   3  12.0   4   0
# 36 Meyers, Paxton     3.37  Jan-00  7.0  0.0   0     0-0   1  10.2   4   4
# Heintz, Danny         6.10     0-1  9.0  0.0   0     0/0   0  10.1   5   8
# 13 McDonough, Tobey   2.10   1-Feb  5.0  5.0   1     0-0   0  30.0  18   8
# 34 Clark, Chris       1.54  Jan-00  7.0  0.0   0     0-0   1  11.2   7   2
# Coady, Owen           2.70  Mar-00  6.0  2.0   0     0/0   0  26.2  17   8
# 30 Narottam, Uday     1.46  Jan-00  6.0  0.0   0     0-0   1  12.1   9   4
# 77 Williamson, Tim    5.18   1-Feb  5.0  5.0   0     0-1   0  24.1  19  14
# 34 Walsh, Mike        4.45  Mar-00  5.0  5.0   0     0-0   0  28.1  22  16
# 25 Stone, Adam        3.95   2-Jan  4.0  4.0   0     0-1   0  13.2  11  15
# 3 Olsen, Bobby        3.10     0-1  6.0  3.0   0     0-0   0  29.0  25  14
# ...
